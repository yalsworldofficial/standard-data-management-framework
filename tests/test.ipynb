# %%
inputstr = '[{"check_table_name": "demo.customers", "standard_checks_passed": true, "standard_checks_result": [{"check_name": "_check_primary_key", "column": "alpha3-b", "passed": true, "bad_count": 0, "total_count": 100, "failure_percentage": 0.0, "failure_ratio": 0.0, "threshold": 0, "threshold_percentage": 0.0}, {"check_name": "_check_nulls", "column": "english", "passed": true, "bad_count": 0, "total_count": 100, "failure_percentage": 0.0, "failure_ratio": 0.0, "threshold": 0, "threshold_percentage": 0.0}], "comprehensive_passed": null, "comprehensive_results": [{"table": "demo.customers", "check_name": "Some unique check name", "load_stage": "PRE_LOAD", "query": "Select 1;", "failed_records": 1, "threshold": 0, "status": "FAILED", "severity": "ERROR", "did_check_pass": false}, {"table": "demo.customers", "check_name": "Some unique check name 1", "load_stage": "PRE_LOAD", "query": "Select 1;", "failed_records": 1, "threshold": 0, "status": "FAILED", "severity": "ERROR", "did_check_pass": false}, {"table": "demo.customers", "check_name": "Some unique check name 2", "load_stage": "PRE_LOAD", "query": "Select 1;", "failed_records": 1, "threshold": 0, "status": "FAILED", "severity": "WARNING", "did_check_pass": false}, {"table": "demo.customers", "check_name": "Some unique check name 3", "load_stage": "POST_LOAD", "query": "Select 1;", "failed_records": 1, "threshold": 0, "status": "FAILED", "severity": "WARNING", "did_check_pass": false}, {"table": "demo.customers", "check_name": "Some unique check name 3", "load_stage": "POST_LOAD", "query": "Select 1;", "failed_records": 1, "threshold": 0, "status": "FAILED", "severity": "WARNING", "did_check_pass": false}], "feed_id": 1, "system_name": "YALS_WORLD", "subsystem_name": "GENERIC", "category": "CODES", "sub_category": "COUNTRY", "data_flow_direction": "SOURCE_TO_BRONZE", "residing_layer": "SOURCE", "feed_name": "country_codes", "feed_type": "UNITY_CATALOG", "load_type": "FULL_LOAD", "target_table_name": "t_country_codes", "comprehensive_pre_load_passed": true, "can_ingest": false, "comprehensive_post_load_passed": false}, {"check_table_name": "demo.customers", "standard_checks_passed": true, "standard_checks_result": [{"check_name": "_check_primary_key", "column": "alpha3-b", "passed": true, "bad_count": 0, "total_count": 100, "failure_percentage": 0.0, "failure_ratio": 0.0, "threshold": 0, "threshold_percentage": 0.0}, {"check_name": "_check_nulls", "column": "english", "passed": true, "bad_count": 0, "total_count": 100, "failure_percentage": 0.0, "failure_ratio": 0.0, "threshold": 0, "threshold_percentage": 0.0}], "comprehensive_passed": null, "comprehensive_results": [{"table": "demo.customers", "check_name": "Some unique check name", "load_stage": "PRE_LOAD", "query": "Select 1;", "failed_records": 1, "threshold": 0, "status": "FAILED", "severity": "ERROR", "did_check_pass": false}, {"table": "demo.customers", "check_name": "Some unique check name 1", "load_stage": "PRE_LOAD", "query": "Select 1;", "failed_records": 1, "threshold": 0, "status": "FAILED", "severity": "ERROR", "did_check_pass": false}, {"table": "demo.customers", "check_name": "Some unique check name 2", "load_stage": "PRE_LOAD", "query": "Select 1;", "failed_records": 1, "threshold": 0, "status": "FAILED", "severity": "WARNING", "did_check_pass": false}, {"table": "demo.customers", "check_name": "Some unique check name 3", "load_stage": "POST_LOAD", "query": "Select 1;", "failed_records": 1, "threshold": 0, "status": "FAILED", "severity": "WARNING", "did_check_pass": false}, {"table": "demo.customers", "check_name": "Some unique check name 3", "load_stage": "POST_LOAD", "query": "Select 1;", "failed_records": 1, "threshold": 0, "status": "FAILED", "severity": "WARNING", "did_check_pass": false}], "feed_id": 2, "system_name": "YALS_WORLD", "subsystem_name": "DATA_ENRICHMENT", "category": "CODES", "sub_category": "LANGUAGE", "data_flow_direction": "SOURCE_TO_BRONZE", "residing_layer": "SOURCE", "feed_name": "language_codes", "feed_type": "UNITY_CATALOG", "load_type": "FULL_LOAD", "target_table_name": "t_language_codes", "comprehensive_pre_load_passed": true, "can_ingest": false, "comprehensive_post_load_passed": false}]'
import json
mydict = json.loads(inputstr)

# %%
import pandas as pd

final_feed_status = []
for status in mydict:
    status.pop('standard_checks_result')
    status.pop('comprehensive_results')
    final_feed_status.append(status)

final_feed_status_df = pd.DataFrame(final_feed_status)

file_sheets = []

# %%
ordered_cols = [
    "feed_id",
    "feed_name",
    "system_name",
    "subsystem_name",
    "category",
    "sub_category",
    "data_flow_direction",
    "residing_layer",
    "feed_type",
    "load_type",
    "target_table_name",
    "check_table_name",
    "standard_checks_passed",
    "comprehensive_pre_load_passed",
    "comprehensive_post_load_passed",
    "can_ingest"
]
final_feed_status_df = final_feed_status_df[[c for c in ordered_cols if c in final_feed_status_df.columns]]
final_feed_status_df = final_feed_status_df.sort_values(by="feed_id")
file_sheets.append(final_feed_status_df)

# %%
display(final_feed_status_df)
# Out:
#    feed_id       feed_name system_name   subsystem_name category sub_category  \
# 0        1   country_codes  YALS_WORLD          GENERIC    CODES      COUNTRY
# 1        2  language_codes  YALS_WORLD  DATA_ENRICHMENT    CODES     LANGUAGE
#
#   data_flow_direction residing_layer      feed_type  load_type  \
# 0    SOURCE_TO_BRONZE         SOURCE  UNITY_CATALOG  FULL_LOAD
# 1    SOURCE_TO_BRONZE         SOURCE  UNITY_CATALOG  FULL_LOAD
#
#   target_table_name check_table_name  standard_checks_passed  \
# 0   t_country_codes   demo.customers                    True
# 1  t_language_codes   demo.customers                    True
#
#    comprehensive_pre_load_passed  comprehensive_post_load_passed  can_ingest
# 0                           True                           False       False
# 1                           True                           False       False

# %%
dashboard_cols = [
    "feed_id",
    "feed_name",
    "system_name",
    "subsystem_name",
    "category",
    "sub_category",
    "standard_checks_passed",
    "comprehensive_pre_load_passed",
    "comprehensive_post_load_passed",
    "can_ingest",
]
dashboard_df = final_feed_status_df[[c for c in dashboard_cols if c in final_feed_status_df.columns]]
file_sheets.append(dashboard_df)

# %%
display(dashboard_df)
# Out:
#    feed_id       feed_name system_name   subsystem_name category sub_category  \
# 0        1   country_codes  YALS_WORLD          GENERIC    CODES      COUNTRY
# 1        2  language_codes  YALS_WORLD  DATA_ENRICHMENT    CODES     LANGUAGE
#
#    standard_checks_passed  comprehensive_pre_load_passed  \
# 0                    True                           True
# 1                    True                           True
#
#    comprehensive_post_load_passed  can_ingest
# 0                           False       False
# 1                           False       False
